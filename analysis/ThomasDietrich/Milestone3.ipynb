# %% [markdown]
# # Milestone 3

# %% [markdown]
# ## Task 3:

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
# %matplotlib inline

# %%
#Load and Process Data from Scripts
import sys
sys.path.append("..")
from scripts import project_functions
df = project_functions.load_and_process("C:\\Users\\thoma\\Desktop\\Data301\\Project\\project-group33\\data\\raw\\SharkAttacks_update.csv")
df
# Out:
#         Year          Type     Country               Area  \
# 0     2018.0       Boating         USA         California
# 1     2018.0    Unprovoked         USA            Georgia
# 2     2018.0       Invalid         USA             Hawaii
# 3     2018.0    Unprovoked   AUSTRALIA    New South Wales
# 4     2018.0      Provoked      MEXICO             Colima
# ...      ...           ...         ...                ...
# 6086  1804.0          Boat   AUSTRALIA    New South Wales
# 6087  1803.0  Sea Disaster         USA     South Carolina
# 6088  1803.0    Unprovoked   AUSTRALIA  Western Australia
# 6089  1802.0    Unprovoked       INDIA                NaN
# 6090  1800.0    Unprovoked  SEYCHELLES           St. Anne
#
#                              Activity Sex   Fatal
# 0                            Paddling    F  False
# 1                            Standing    F  False
# 2                             Surfing    M  False
# 3                             Surfing    M  False
# ...

# %%
df['Year'] = pd.to_datetime(df.Year, format='%Y')
df['Year'] = pd.DatetimeIndex(df['Year']).year
df
# Out:
#       Year          Type     Country               Area  \
# 0     2018       Boating         USA         California
# 1     2018    Unprovoked         USA            Georgia
# 2     2018       Invalid         USA             Hawaii
# 3     2018    Unprovoked   AUSTRALIA    New South Wales
# 4     2018      Provoked      MEXICO             Colima
# ...    ...           ...         ...                ...
# 6086  1804          Boat   AUSTRALIA    New South Wales
# 6087  1803  Sea Disaster         USA     South Carolina
# 6088  1803    Unprovoked   AUSTRALIA  Western Australia
# 6089  1802    Unprovoked       INDIA                NaN
# 6090  1800    Unprovoked  SEYCHELLES           St. Anne
#
#                              Activity Sex   Fatal
# 0                            Paddling    F  False
# 1                            Standing    F  False
# 2                             Surfing    M  False
# 3                             Surfing    M  False
# ...

# %%
df.to_csv("C:\\Users\\thoma\\Desktop\\Data301\\Project\\project-group33\\data\\processed\\Dataframe_processed.csv", index=False)
